# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tensorflow as tf

params1 = {'naf': {'learningParameters': {'discount': 0.75,
                                           'learning_rate': 0.001},
                    'nnpParameters': {'hidden_layers': [5],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [10, 10, 10],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [400],
                                      'nonlinearity': tf.nn.relu}},
            'strat': {'decay': 1000, 'scale': 1.0}}

params2 = {'naf': {'learningParameters': {'discount': 0.5,
                                           'learning_rate': 0.001},
                    'nnpParameters': {'hidden_layers': [5],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [10, 10, 10],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [400],
                                      'nonlinearity': tf.nn.relu}},
            'strat': {'decay': 1000, 'scale': 1.0}}

params3 = {'naf': {'learningParameters': {'discount': 0.75,
                                           'learning_rate': 0.001},
                    'nnpParameters': {'hidden_layers': [5],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [20, 20, 20],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [400],
                                      'nonlinearity': tf.nn.relu}},
            'strat': {'decay': 1000, 'scale': 1.0}}

params4 = {'naf': {'learningParameters': {'discount': 0.75,
                                           'learning_rate': 0.001},
                    'nnpParameters': {'hidden_layers': [5],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [10, 10, 10],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [800],
                                      'nonlinearity': tf.nn.relu}},
            'strat': {'decay': 1000, 'scale': 1.0}}

params5 = {'naf': {'learningParameters': {'discount': 0.75,
                                           'learning_rate': 0.001},
                    'nnpParameters': {'hidden_layers': [5],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [10, 10, 10],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [800],
                                      'nonlinearity': tf.nn.relu}},
            'strat': {'decay': 400, 'scale': 1.0}}

params6 = {'naf': {'learningParameters': {'discount': 0.05,
                                           'learning_rate': 0.001},
                    'nnpParameters': {'hidden_layers': [5],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [10, 10, 10],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [400],
                                      'nonlinearity': tf.nn.relu}},
            'strat': {'decay': 400, 'scale': 1.0}}

params7 = {'naf': {'learningParameters': {'discount': 0.94999999999999996,
                                           'learning_rate': 0.0001},
                    'nnpParameters': {'hidden_layers': [1],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [10],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [200],
                                      'nonlinearity': tf.nn.tanh}},
            'strat': {'decay': 1000, 'scale': 1.0}}

params8 = {'naf': {'learningParameters': {'discount': 0.94999999999999996,
                                           'learning_rate': 0.00001},
                    'nnpParameters': {'hidden_layers': [1],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [10],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [200],
                                      'nonlinearity': tf.nn.tanh}},
            'strat': {'decay': 1000, 'scale': 1.0}}

params9 = {'naf': {'learningParameters': {'discount': 0.94999999999999996,
                                           'learning_rate': 0.0001},
                    'nnpParameters': {'hidden_layers': [1],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [20],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [400],
                                      'nonlinearity': tf.nn.tanh}},
            'strat': {'decay': 1000, 'scale': 1.0}}

params10 = {'naf': {'learningParameters': {'discount': 0.94999999999999996,
                                           'learning_rate': 0.0001},
                    'nnpParameters': {'hidden_layers': [1, 1],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [10, 10],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [200, 200],
                                      'nonlinearity': tf.nn.tanh}},
            'strat': {'decay': 1000, 'scale': 1.0}}

params11 = {'naf': {'learningParameters': {'discount': 0.94999999999999996,
                                           'learning_rate': 0.001},
                    'nnpParameters': {'hidden_layers': [1, 1],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [10, 10],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [200, 200],
                                      'nonlinearity': tf.nn.tanh}},
            'strat': {'decay': 1000, 'scale': 0.5}}

params12 = {'naf': {'learningParameters': {'discount': 0.94999999999999996,
                                           'learning_rate': 0.001},
                    'nnpParameters': {'hidden_layers': [1, 1],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [10, 10],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [200, 200],
                                      'nonlinearity': tf.nn.tanh}},
            'strat': {'decay': 1000, 'scale': 1.0}}

params13 = {'naf': {'learningParameters': {'discount': 0.94999999999999996,
                                           'learning_rate': 0.001},
                    'nnpParameters': {'hidden_layers': [1, 1],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [10, 10],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [200, 200],
                                      'nonlinearity': tf.nn.tanh}},
            'strat': {'decay': 200, 'scale': .5}}

import gym
import gym.wrappers
import pprint
from trainer import naftrainer

# %matplotlib inline

nParameters = 10
attempts = 5
max_epochs = 600
results = []
parameters = [params13, params11, params12, params7, params8, params9, params10, params1, params2, params3, params4, params5, params6]
for i, params in enumerate(parameters):
    print i, len(parameters), params
    pprint.pprint(params)
    rewards = []
    envs = []
    for j in range(attempts):
        env = gym.make('InvertedDoublePendulum-v1')
        env = gym.wrappers.Monitor(env, '/tmp/inverted-pendulum-' + str(i) + '-' + str(j), force=True)
        agent, reward = naftrainer.train(env, params, max_epochs=max_epochs)
        print j, reward
        #env.close()
        rewards.append(reward)
        envs.append(env)
    results.append({'params': params, 'agent': agent, 'rewards': rewards, 'envs': envs})
        
    import matplotlib.pyplot as plt
    r = results[-1]
    plt.hist(r['rewards'])
    plt.show()
# Out:
# [2017-02-28 17:49:20,709] Making new env: InvertedDoublePendulum-v1
# 0 13 {'strat': {'scale': 0.5, 'decay': 200}, 'naf': {'nnqParameters': {'hidden_layers': [10, 10], 'nonlinearity': <function tanh at 0x7eff3924d578>}, 'learningParameters': {'discount': 0.95, 'learning_rate': 0.001}, 'nnpParameters': {'hidden_layers': [1, 1], 'nonlinearity': <function relu at 0x7eff39135848>}, 'nnvParameters': {'hidden_layers': [200, 200], 'nonlinearity': <function tanh at 0x7eff3924d578>}}}
# {'naf': {'learningParameters': {'discount': 0.95, 'learning_rate': 0.001},
#          'nnpParameters': {'hidden_layers': [1, 1],
#                            'nonlinearity': <function relu at 0x7eff39135848>},
#          'nnqParameters': {'hidden_layers': [10, 10],
#                            'nonlinearity': <function tanh at 0x7eff3924d578>},
#          'nnvParameters': {'hidden_layers': [200, 200],
#                            'nonlinearity': <function tanh at 0x7eff3924d578>}},
#  'strat': {'decay': 200, 'scale': 0.5}}
# [-1.] [ 1.]
# (11,)
# (11,)
# Epoch 0 Reward 45.2016529123
# Epoch 100 Reward 193.469374896
# Epoch 200 Reward 230.5437306
# Epoch 300 Reward 306.475054646
# Epoch 400 Reward 531.13523912
# Epoch 500 Reward 279.052943132
# [2017-02-28 17:54:33,466] Making new env: InvertedDoublePendulum-v1
# 0 465.352242879
# [-1.] [ 1.]
# (11,)
# (11,)
# Epoch 0 Reward 45.1582982345
# Epoch 100 Reward 36.1682776153
# Epoch 200 Reward 63.6609988482
# Epoch 300 Reward 101.171130161
# Epoch 400 Reward 73.466217973
# Epoch 500 Reward 73.3521732851
# [2017-02-28 17:56:15,664] Making new env: InvertedDoublePendulum-v1
# 1 73.1628104891
# [-1.] [ 1.]
# (11,)
# (11,)
# Epoch 0 Reward 54.1554773723
# Epoch 100 Reward 119.950094863
# Epoch 200 Reward 203.827823366
# Epoch 300 Reward 250.991898158
# Epoch 400 Reward 203.250577212
# Epoch 500 Reward 240.622713144
# [2017-02-28 18:01:38,880] Making new env: InvertedDoublePendulum-v1
# 2 231.356209681
# [-1.] [ 1.]
# (11,)
# (11,)
# Epoch 0 Reward 44.903903039
# Epoch 100 Reward 92.1476102077
# Epoch 200 Reward 259.397131133
# Epoch 300 Reward 258.654374646
# Epoch 400 Reward 325.068611251
# Epoch 500 Reward 342.022209936
# [2017-02-28 18:08:25,807] Making new env: InvertedDoublePendulum-v1
# 3 286.777187096
# [-1.] [ 1.]
# (11,)
# (11,)
# Epoch 0 Reward 91.9374860213
# Epoch 100 Reward 91.8548245364
# Epoch 200 Reward 176.394121318
# Epoch 300 Reward 297.339171145
# Epoch 400 Reward 240.066141107
# Epoch 500 Reward 465.933694307
# 4 521.274968115
# [2017-02-28 18:15:54,443] Making new env: InvertedDoublePendulum-v1
# 1 13 {'strat': {'scale': 0.5, 'decay': 1000}, 'naf': {'nnqParameters': {'hidden_layers': [10, 10], 'nonlinearity': <function tanh at 0x7eff3924d578>}, 'learningParameters': {'discount': 0.95, 'learning_rate': 0.001}, 'nnpParameters': {'hidden_layers': [1, 1], 'nonlinearity': <function relu at 0x7eff39135848>}, 'nnvParameters': {'hidden_layers': [200, 200], 'nonlinearity': <function tanh at 0x7eff3924d578>}}}
# {'naf': {'learningParameters': {'discount': 0.95, 'learning_rate': 0.001},
#          'nnpParameters': {'hidden_layers': [1, 1],
#                            'nonlinearity': <function relu at 0x7eff39135848>},
#          'nnqParameters': {'hidden_layers': [10, 10],
#                            'nonlinearity': <function tanh at 0x7eff3924d578>},
#          'nnvParameters': {'hidden_layers': [200, 200],
#                            'nonlinearity': <function tanh at 0x7eff3924d578>}},
#  'strat': {'decay': 1000, 'scale': 0.5}}
# [-1.] [ 1.]
# (11,)
# (11,)
# Epoch 0 Reward 45.5270277279
# Epoch 100 Reward 129.231319946
# Epoch 200 Reward 231.505622978
# Epoch 300 Reward 231.135839827
# Epoch 400 Reward 192.952187774
# Epoch 500 Reward 278.043613615
# [2017-02-28 18:20:46,172] Making new env: InvertedDoublePendulum-v1
# 0 493.406530444
# [-1.] [ 1.]
# (11,)
# (11,)
# Epoch 0 Reward 45
# [-1.] [ 1.]
# (11,)
# (11,)
# Epoch 0 Reward 35.9975414855
# Epoch 100 Reward 26.776907908
# Epoch 200 Reward 45.207800008
# Epoch 300 Reward 54.4368842934
# Epoch 400 Reward 54.387844051
# Epoch 500 Reward 45.4623609528
# [2017-02-28 19:52:51,037] Making new env: InvertedDoublePendulum-v1
# 3 45.3461366844
# [-1.] [ 1.]
# (11,)
# (11,)
# Epoch 0 Reward 44.975009418
# Epoch 100 Reward 54.0978401536
# Epoch 200 Reward 73.2330353136
# Epoch 300 Reward 73.37814011
# Epoch 400 Reward 63.5473182902
# Epoch 500 Reward 63.5991294184
# 4 54.7246581655

# %%
gym.upload('/tmp/inverted-pendulum-1-0', api_key='sk_zPQUIRT3QNJwr2taOCDWA')

# %%
results[0]
# Out:
# {'agent': <agents.agent.Agent at 0x7eff041f9110>,
#  'envs': [<gym.envs.mujoco.inverted_double_pendulum.InvertedDoublePendulumEnv at 0x7eff0e9d9cd0>,
#   <gym.envs.mujoco.inverted_double_pendulum.InvertedDoublePendulumEnv at 0x7eff0c0bed50>,
#   <gym.envs.mujoco.inverted_double_pendulum.InvertedDoublePendulumEnv at 0x7eff2d1dc950>,
#   <gym.envs.mujoco.inverted_double_pendulum.InvertedDoublePendulumEnv at 0x7eff056e0190>,
#   <gym.envs.mujoco.inverted_double_pendulum.InvertedDoublePendulumEnv at 0x7eff049d0d50>],
#  'params': {'naf': {'learningParameters': {'discount': 0.95,
#     'learning_rate': 0.001},
#    'nnpParameters': {'hidden_layers': [1, 1],
#     'nonlinearity': <function tensorflow.python.ops.gen_nn_ops.relu>},
#    'nnqParameters': {'hidden_layers': [10, 10],
#     'nonlinearity': <function tensorflow.python.ops.math_ops.tanh>},
#    'nnvParameters': {'hidden_layers': [200, 200],
#     'nonlinearity': <function tensorflow.python.ops.math_ops.tanh>}},
#   'strat': {'decay': 200, 'scale': 0.5}},
#  'rewards': [465.35224287885165,
#   73.162810489148953,
#   231.35620968057026,
#   286.77718709617631,
#   521.27496811464994]}

# %%
import tensorflow as tf

params = {'naf': {'learningParameters': {'discount': 0.94999999999999996,
                                           'learning_rate': 0.001},
                    'nnpParameters': {'hidden_layers': [1, 1],
                                      'nonlinearity': tf.nn.relu},
                    'nnqParameters': {'hidden_layers': [40, 40],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [800, 800],
                                      'nonlinearity': tf.nn.tanh}},
            'strat': {'decay': 10000, 'scale': .25}}

params['strat']['max_steps'] = 2000
params['strat']['target'] = 2000

import gym
import gym.wrappers
import pprint
from trainer import naftrainer

env = gym.make('InvertedDoublePendulum-v1')
env = gym.wrappers.Monitor(env, '/tmp/inverted-pendulum-final', force=True)
agent, reward = naftrainer.train(env, params, max_epochs=1000, writeevery=10)
env.close()
# Out:
# [2017-03-03 23:14:42,493] Making new env: InvertedDoublePendulum-v1
# [2017-03-03 23:14:42,795] DEPRECATION WARNING: env.spec.timestep_limit has been deprecated. Replace your call to `env.spec.timestep_limit` with `env.spec.tags.get('wrapper_config.TimeLimit.max_episode_steps')`. This change was made 12/28/2016 and is included in version 0.7.0
# [2017-03-03 23:14:42,797] Clearing 18 monitor files from previous run (because force=True was provided)
# [-1.] [ 1.]
# (11,)
# (11,)
# [2017-03-03 23:14:44,136] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.23566.video000000.mp4
# [2017-03-03 23:14:45,021] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.23566.video000001.mp4
# Epoch 0 Reward 128.775833247
# [2017-03-03 23:14:46,167] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.23566.video000008.mp4
# Epoch 10 Reward 73.3037826301
# Epoch 20 Reward 157.539997639
# [2017-03-03 23:14:51,551] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.23566.video000027.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-f063458a2bbb> in <module>()
#      21 env = gym.make('InvertedDoublePendulum-v1')
#      22 env = gym.wrappers.Monitor(env, '/tmp/inverted-pendulum-final', force=True)
# ---> 23 agent, reward = naftrainer.train(env, params, max_epochs=1000, writeevery=10)
#      24 env.close()
#
# /home/ygreif/qlearning/trainer/naftrainer.pyc in train(env, parameters, max_epochs, writeevery, validate)
#      41     for epoch in range(max_epochs):
#      42         strat = agents.agent.DeltaStrategy(epoch=epoch, **parameters['strat'])
# ---> 43         r = a.train_epoch(env, strat)
#      44         if epoch % writeevery == 0:
#      45             print "Epoch", epoch, "Reward", r
#
# /home/ygreif/qlearning/agents/agent.pyc in train_epoch(self, env, strat, learn)
#      49             self.memory.append(state, action, reward, next_state, done)
#      50             if learn:
# ---> 51                 self.learn()
#      52             cum_reward += reward
#      53             state = next_state
#
# /home/ygreif/qlearning/agents/agent.pyc in learn(self)
#      61         minibatch = self.memory.minibatch(self.minibatch_size)
#      62         self.q.trainstep(minibatch.state, minibatch.actions,
# ---> 63                          minibatch.rewards, minibatch.next_state, minibatch.terminals)
#
# /home/ygreif/qlearning/agents/naf.pyc in trainstep(self, state, action, rewards, next_state, terminals)
#     152
#     153     def trainstep(self, state, action, rewards, next_state, terminals):
# --> 154         target = self.calcq(rewards, next_state, terminals)
#     155         return self.session.run(self.train_step, feed_dict={self.target: target, self.vx: state, self.px: state, self.qx: state, self.action_inp: action})
#     156
#
# /home/ygreif/qlearning/agents/naf.pyc in calcq(self, rewards, next_state, terminals)
#     139
#     140     def calcq(self, rewards, next_state, terminals):
# --> 141         return self.session.run(self.update, feed_dict={self.r: rewards, self.vx: next_state, self.terminal: terminals})
#     142
#     143     def storedq(self, state, action):
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import tensorflow as tf

params = {'naf': {'learningParameters': {'discount': 0.99,
                                           'learning_rate': 0.005},
                    'nnpParameters': {'hidden_layers': [1],
                                      'nonlinearity': tf.nn.tanh},
                    'nnqParameters': {'hidden_layers': [100, 50],
                                      'nonlinearity': tf.nn.tanh},
                    'nnvParameters': {'hidden_layers': [10],
                                      'nonlinearity': tf.nn.tanh}},
            'strat': {'decay': 10000, 'scale': .25}}

params['strat']['max_steps'] = 20000
params['strat']['target'] = 20000

import gym
import gym.wrappers
import pprint
from trainer import naftrainer

env = gym.make('InvertedDoublePendulum-v1')
#env = gym.wrappers.Monitor(env, '/tmp/inverted-pendulum-biggerp', force=True)
agent, reward = naftrainer.train(env, params, max_epochs=1000, writeevery=10)
#env.close()
# Out:
# [2017-03-03 23:15:37,671] Making new env: InvertedDoublePendulum-v1
# [-1.] [ 1.]
# (11,)
# (11,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6e2724ebb6f0> in <module>()
#      21 env = gym.make('InvertedDoublePendulum-v1')
#      22 #env = gym.wrappers.Monitor(env, '/tmp/inverted-pendulum-biggerp', force=True)
# ---> 23 agent, reward = naftrainer.train(env, params, max_epochs=1000, writeevery=10)
#      24 #env.close()
#
# /home/ygreif/qlearning/trainer/naftrainer.pyc in train(env, parameters, max_epochs, writeevery, validate)
#      36
#      37 def train(env, parameters, max_epochs=400, writeevery=100, validate=False):
# ---> 38     naf = agents.naf.SetupNAF.setup(env, **parameters['naf'])
#      39     a = agents.agent.Agent(naf)
#      40     plots = []
#
# /home/ygreif/qlearning/agents/naf.pyc in setup(cls, env, nnvParameters, nnpParameters, nnqParameters, learningParameters)
#      36             states = [obs_space_small.sample() for i in range(n)]
#      37             naf.coldstart(states, targets)
# ---> 38             states = [obs_space_small.sample() for i in range(n)]
#      39             actions = naf.actions(states)
#      40             if np.all(np.less(actions, high)) and np.all(np.greater(actions, low)):
#
# KeyboardInterrupt:

# %%
import tensorflow as tf

# %matplotlib inline


params = {'naf': {'learningParameters': {'discount': 0.94999999999999996,
                                        'learning_rate': 0.001,
                                        'keep_prob': .8},
                    'nnpParameters': {'hidden_layers': [2, 2],
                                      'nonlinearity': tf.nn.tanh,
                                      'use_dropout': False},
                    'nnqParameters': {'hidden_layers': [800, 800],
                                      'nonlinearity': tf.nn.tanh,
                                      'use_dropout': True},
                    'nnvParameters': {'hidden_layers': [1600, 1600],
                                      'nonlinearity': tf.nn.tanh},
                                       'use_dropout': True},
            'strat': {'decay': 10000, 'scale': .25}}

params['strat']['max_steps'] = 2000
params['strat']['target'] = 2000

import gym
import gym.wrappers
import pprint
from trainer import naftrainer

env = gym.make('InvertedDoublePendulum-v1')
validation_env = gym.make('InvertedDoublePendulum-v1')
env = gym.wrappers.Monitor(env, '/tmp/inverted-pendulum-final', force=True)
agent, reward, plots = naftrainer.train(env, params, max_epochs=4000, writeevery=100, validate=True, validation_env=validation_env)
env.close()
# Out:
# [2017-03-04 10:49:06,768] Making new env: InvertedDoublePendulum-v1
# [2017-03-04 10:49:06,982] Making new env: InvertedDoublePendulum-v1
# [2017-03-04 10:49:06,988] DEPRECATION WARNING: env.spec.timestep_limit has been deprecated. Replace your call to `env.spec.timestep_limit` with `env.spec.tags.get('wrapper_config.TimeLimit.max_episode_steps')`. This change was made 12/28/2016 and is included in version 0.7.0
# [2017-03-04 10:49:06,989] Creating monitor directory /tmp/inverted-pendulum-final
# [-1.] [ 1.]
# (11,)
# (11,)
# [2017-03-04 10:49:46,392] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.2900.video000000.mp4
# [2017-03-04 10:49:47,400] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.2900.video000001.mp4
# Epoch 0 Reward 73.2223594006
# [2017-03-04 10:49:48,825] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.2900.video000008.mp4
# [2017-03-04 10:49:58,094] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.2900.video000027.mp4
# [2017-03-04 10:50:13,663] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.2900.video000064.mp4
# Epoch 100 Reward 82.7233324508
# [2017-03-04 10:52:06,191] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.2900.video000125.mp4
# Epoch 200 Reward 92.200530249
# [2017-03-04 10:55:22,785] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.2900.video000216.mp4
# Epoch 300 Reward 129.069064496
# [2017-03-04 11:00:10,941] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.2900.video000343.mp4
# Epoch 400 Reward 194.043771931
# Epoch 500 Reward 101.201752989
# [2017-03-04 11:09:48,076] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.2900.video000512.mp4
# Epoch 600 Reward 147.333938776
# Epoch 700 Reward 175.54129039
# [2017-03-04 11:23:07,561] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.2900.video000729.mp4
# Epoch 800 Reward 315.192179697
# Epoch 900 Reward 72.9937822155
# [2017-03-04 11:38:18,105] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.2900.video001000.mp4
# Epoch 1000 Reward 278.876451542
# Epoch 1100 Reward 111.106349482
# Epoch 1200 Reward 110.624974716
# Epoch 1300 Reward 119.860392322
# Epoch 1400 Reward 82.8355252984
# Epoch 1500 Reward 277.973737396
# Epoch 1600 Reward 266.992645229
# Epoch 1700 Reward 129.268904441
# Epoch 1800 Reward 101.206580382
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-dce3c338004d> in <module>()
#      26 validation_env = gym.make('InvertedDoublePendulum-v1')
#      27 env = gym.wrappers.Monitor(env, '/tmp/inverted-pendulum-final', force=True)
# ---> 28 agent, reward, plots = naftrainer.train(env, params, max_epochs=4000, writeevery=100, validate=True, validation_env=validation_env)
#      29 env.close()
#
# /home/ygreif/qlearning/trainer/naftrainer.pyc in train(env, parameters, max_epochs, writeevery, validate, validation_env)
#      49             if validate and epoch > 0:
#      50                 insample, outsample, onstrat = agents.validation.validate(
# ---> 51                     validation_env, a, 5000, 60, log=False)
#      52                 agents.validation.plot(insample, outsample, onstrat)
#      53     return a, r, plots
#
# /home/ygreif/qlearning/agents/validation.pyc in validate(env, agent, samples, iters, log)
#      36         for minibatch, losses in [(insample_minibatch, insample_loss), (outsample_minibatch, outsample_loss), (onstrat_minibatch, onstrat_loss)]:
#      37             losses.append(q.calcloss(minibatch.state, minibatch.actions,
# ---> 38                                      minibatch.rewards, minibatch.next_state, minibatch.terminals))
#      39         # handle insample
#      40         minibatch = insample_memory.minibatch(samples)
#
# /home/ygreif/qlearning/agents/naf.pyc in calcloss(self, state, action, rewards, next_state, terminals)
#     147
#     148     def calcloss(self, state, action, rewards, next_state, terminals):
# --> 149         target = self.calcq(rewards, next_state, terminals)
#     150         return self.session.run(self.loss, feed_dict={self.target: target, self.vx: state, self.px: state, self.qx: state, self.action_inp: action, nn.keep_prob: self.keep_prob})
#     151
#
# /home/ygreif/qlearning/agents/naf.pyc in calcq(self, rewards, next_state, terminals)
#     141
#     142     def calcq(self, rewards, next_state, terminals):
# --> 143         return self.session.run(self.update, feed_dict={self.r: rewards, self.vx: next_state, self.terminal: terminals, nn.keep_prob: 1.0})
#     144
#     145     def storedq(self, state, action):
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
from agents import validation

insample, outsample, onstrat = validation.validate(env, agent, 5000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-66546d170812> in <module>()
#       1 from agents import validation
#       2
# ----> 3 insample, outsample, onstrat = validation.validate(env, agent, 5000)
#
# NameError: name 'agent' is not defined

# %%
# %matplotlib inline
for p in plots:
    p.show()
#import matplotlib.pyplot as plt

#plt.plot(insample, label="in sample")
#plt.plot(outsample, label="out sample")
#plt.plot(onstrat, label="on strat")
#plt.legend()
#plt.close()

# %%
# import tensorflow as tf

# %matplotlib inline


params = {'naf': {'learningParameters': {'discount': 0.99,
                                        'learning_rate': 0.001,
                                        'keep_prob': .9},
                    'nnpParameters': {'hidden_layers': [1, 1],
                                      'nonlinearity': tf.nn.tanh,
                                      'use_dropout': False},
                    'nnqParameters': {'hidden_layers': [400, 400],
                                      'nonlinearity': tf.nn.tanh,
                                      'use_dropout': True},
                    'nnvParameters': {'hidden_layers': [800, 800],
                                      'nonlinearity': tf.nn.tanh,
                                       'use_dropout': True}},
            'strat': {'decay': 10000, 'scale': .25}}

params['strat']['max_steps'] = 40000
params['strat']['target'] = 40000

import gym
import gym.wrappers
import pprint
from trainer import naftrainer

env = gym.make('InvertedDoublePendulum-v1')
validation_env = gym.make('InvertedDoublePendulum-v1')
env = gym.wrappers.Monitor(env, '/tmp/inverted-pendulum-final', force=True)
agent, reward, plots = naftrainer.train(env, params, max_epochs=4000, writeevery=100, validate=True, validation_env=validation_env)
env.close()
# Out:
# [2017-03-04 16:25:44,046] Making new env: InvertedDoublePendulum-v1
# [2017-03-04 16:25:44,051] Making new env: InvertedDoublePendulum-v1
# [2017-03-04 16:25:44,060] DEPRECATION WARNING: env.spec.timestep_limit has been deprecated. Replace your call to `env.spec.timestep_limit` with `env.spec.tags.get('wrapper_config.TimeLimit.max_episode_steps')`. This change was made 12/28/2016 and is included in version 0.7.0
# [2017-03-04 16:25:44,061] Clearing 18 monitor files from previous run (because force=True was provided)
# [-1.] [ 1.]
# (11,)
# (11,)
# [2017-03-04 16:26:02,841] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.4.2430.video000000.mp4
# [2017-03-04 16:26:03,592] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.4.2430.video000001.mp4
# Epoch 0 Reward 45.3297397008
# [2017-03-04 16:26:04,298] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.4.2430.video000008.mp4
# [2017-03-04 16:26:08,294] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.4.2430.video000027.mp4
# [2017-03-04 16:26:25,845] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.4.2430.video000064.mp4
# Epoch 100 Reward 81.9951964805
# [2017-03-04 16:27:53,326] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.4.2430.video000125.mp4
# Epoch 200 Reward 370.904428107
# [2017-03-04 16:31:07,008] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.4.2430.video000216.mp4
# Epoch 300 Reward 1199.07456319
# [2017-03-04 16:41:20,043] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.4.2430.video000343.mp4
# Epoch 400 Reward 4700.90075809
# Epoch 500 Reward 2967.77670577
# [2017-03-04 17:28:56,032] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.4.2430.video000512.mp4
# Epoch 600 Reward 6427.82735694
# Epoch 700 Reward 1655.21683418
# [2017-03-04 19:33:42,402] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.4.2430.video000729.mp4
# Epoch 800 Reward 119.692443997
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-bb02cb417346> in <module>()
#      29 validation_env = gym.make('InvertedDoublePendulum-v1')
#      30 env = gym.wrappers.Monitor(env, '/tmp/inverted-pendulum-final', force=True)
# ---> 31 agent, reward, plots = naftrainer.train(env, params, max_epochs=4000, writeevery=100, validate=True, validation_env=validation_env)
#      32 env.close()
#
# /home/ygreif/qlearning/trainer/naftrainer.pyc in train(env, parameters, max_epochs, writeevery, validate, validation_env)
#      44     for epoch in range(max_epochs):
#      45         strat = agents.agent.DeltaStrategy(epoch=epoch, **parameters['strat'])
# ---> 46         r = a.train_epoch(env, strat)
#      47         if epoch % writeevery == 0:
#      48             print "Epoch", epoch, "Reward", r
#
# /home/ygreif/qlearning/agents/agent.pyc in train_epoch(self, env, strat, learn)
#      49             self.memory.append(state, action, reward, next_state, done)
#      50             if learn:
# ---> 51                 self.learn()
#      52             cum_reward += reward
#      53             state = next_state
#
# /home/ygreif/qlearning/agents/agent.pyc in learn(self)
#      63         minibatch = self.memory.minibatch(self.minibatch_size)
#      64         self.q.trainstep(minibatch.state, minibatch.actions,
# ---> 65                          minibatch.rewards, minibatch.next_state, minibatch.terminals)
#
# /home/ygreif/qlearning/agents/naf.pyc in trainstep(self, state, action, rewards, next_state, terminals)
#     155     def trainstep(self, state, action, rewards, next_state, terminals):
#     156         target = self.calcq(rewards, next_state, terminals)
# --> 157         return self.session.run(self.train_step, feed_dict={self.target: target, self.vx: state, self.px: state, self.qx: state, self.action_inp: action, nn.keep_prob: self.keep_prob})
#     158
#     159     def __exit__(self):
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /home/ygreif/qlearning/env/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import tensorflow as tf

# %matplotlib inline


params = {'naf': {'learningParameters': {'discount': 0.99,
                                        'learning_rate': 0.001,
                                        'keep_prob': .9},
                    'nnpParameters': {'hidden_layers': [1, 1],
                                      'nonlinearity': tf.nn.tanh,
                                      'use_dropout': False},
                    'nnqParameters': {'hidden_layers': [400, 400],
                                      'nonlinearity': tf.nn.tanh,
                                      'use_dropout': True},
                    'nnvParameters': {'hidden_layers': [800, 800],
                                      'nonlinearity': tf.nn.tanh,
                                       'use_dropout': True}},
            'strat': {'decay': 10000, 'scale': .25}}

params['strat']['max_steps'] = 40000
params['strat']['target'] = 40000

import gym
import gym.wrappers
import pprint
from trainer import naftrainer

env = gym.make('InvertedDoublePendulum-v1')
validation_env = gym.make('InvertedDoublePendulum-v1')
env = gym.wrappers.Monitor(env, '/tmp/inverted-pendulum-final', force=True)
agent, reward, plots = naftrainer.train(env, params, max_epochs=1400, writeevery=100, validate=False, validation_env=validation_env)
#env.close()
# Out:
# [2017-03-05 11:47:16,458] Making new env: InvertedDoublePendulum-v1
# [2017-03-05 11:47:16,472] Making new env: InvertedDoublePendulum-v1
# [2017-03-05 11:47:16,478] DEPRECATION WARNING: env.spec.timestep_limit has been deprecated. Replace your call to `env.spec.timestep_limit` with `env.spec.tags.get('wrapper_config.TimeLimit.max_episode_steps')`. This change was made 12/28/2016 and is included in version 0.7.0
# [2017-03-05 11:47:16,479] Clearing 24 monitor files from previous run (because force=True was provided)
# [-1.] [ 1.]
# (11,)
# (11,)
# [2017-03-05 11:47:28,556] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.1.18491.video000000.mp4
# [2017-03-05 11:47:29,013] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.1.18491.video000001.mp4
# Epoch 0 Reward 45.010149129
# [2017-03-05 11:47:29,682] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.1.18491.video000008.mp4
# [2017-03-05 11:47:33,200] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.1.18491.video000027.mp4
# [2017-03-05 11:47:53,157] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.1.18491.video000064.mp4
# Epoch 100 Reward 137.943161205
# [2017-03-05 11:48:47,464] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.1.18491.video000125.mp4
# Epoch 200 Reward 249.861468943
# [2017-03-05 11:51:04,021] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.1.18491.video000216.mp4
# Epoch 300 Reward 147.509751704
# [2017-03-05 11:57:46,812] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.1.18491.video000343.mp4
# Epoch 400 Reward 3595.45682133
# Epoch 500 Reward 1014.2750105
# [2017-03-05 12:42:08,077] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.1.18491.video000512.mp4
# Epoch 600 Reward 463.244780194
# Epoch 700 Reward 9314.85784031
# [2017-03-05 14:15:55,027] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.1.18491.video000729.mp4
# Epoch 800 Reward 7367.95826741
# Epoch 900 Reward 3342.218745

# %%
reward
env.close()
# Out:
# [2017-03-05 11:43:07,602] Finished writing results. You can upload them to the scoreboard via gym.upload('/tmp/inverted-pendulum-final')

# %%
gym.upload('/tmp/inverted-pendulum-final', api_key='sk_zPQUIRT3QNJwr2taOCDWA')
# Out:
# [2017-03-05 11:43:47,081] [InvertedDoublePendulum-v1] Uploading 2000 episodes of training data
# [2017-03-05 11:43:47,667] [InvertedDoublePendulum-v1] Uploading videos of 11 training episodes (167278 bytes)
# [2017-03-05 11:43:47,958] [InvertedDoublePendulum-v1] Creating evaluation object from /tmp/inverted-pendulum-final with learning curve and training video
# [2017-03-05 11:43:48,063]
# ****************************************************
# You successfully uploaded your evaluation on InvertedDoublePendulum-v1 to
# OpenAI Gym! You can find it at:
#
#     https://gym.openai.com/evaluations/eval_yXs5cvtDRieoMDLlOCUG3Q
#
# ****************************************************

# %%
import tensorflow as tf

# %matplotlib inline


params = {'naf': {'learningParameters': {'discount': 0.99,
                                        'learning_rate': 0.001,
                                        'keep_prob': .9},
                    'nnpParameters': {'hidden_layers': [2, 2],
                                      'nonlinearity': tf.nn.tanh,
                                      'use_dropout': False},
                    'nnqParameters': {'hidden_layers': [600, 600],
                                      'nonlinearity': tf.nn.tanh,
                                      'use_dropout': True},
                    'nnvParameters': {'hidden_layers': [1000, 1000],
                                      'nonlinearity': tf.nn.tanh,
                                       'use_dropout': True}},
            'strat': {'decay': 10000, 'scale': .25}}

params['strat']['max_steps'] = 40000
params['strat']['target'] = 40000

import gym
import gym.wrappers
import pprint
from trainer import naftrainer

env = gym.make('InvertedDoublePendulum-v1')
validation_env = gym.make('InvertedDoublePendulum-v1')
env = gym.wrappers.Monitor(env, '/tmp/inverted-pendulum-final', force=True)
agent, reward, plots = naftrainer.train(env, params, max_epochs=1400, writeevery=10, validate=False, validation_env=validation_env)
env.close()
# Out:
# [2017-03-05 21:52:13,136] Making new env: InvertedDoublePendulum-v1
# [2017-03-05 21:52:13,306] Making new env: InvertedDoublePendulum-v1
# [2017-03-05 21:52:13,312] DEPRECATION WARNING: env.spec.timestep_limit has been deprecated. Replace your call to `env.spec.timestep_limit` with `env.spec.tags.get('wrapper_config.TimeLimit.max_episode_steps')`. This change was made 12/28/2016 and is included in version 0.7.0
# [2017-03-05 21:52:13,313] Clearing 18 monitor files from previous run (because force=True was provided)
# [-1.] [ 1.]
# (11,)
# (11,)
# [2017-03-05 21:52:41,436] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.6051.video000000.mp4
# [2017-03-05 21:52:41,958] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.6051.video000001.mp4
# Epoch 0 Reward 54.4335034907
# [2017-03-05 21:52:42,765] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.6051.video000008.mp4
# Epoch 10 Reward 54.7970593628
# Epoch 20 Reward 44.6705905107
# [2017-03-05 21:52:48,005] Starting new video recorder writing to /tmp/inverted-pendulum-final/openaigym.video.0.6051.video